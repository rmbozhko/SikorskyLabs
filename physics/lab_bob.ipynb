# %%
import numpy as np

positionData = np.array([1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5])
oscillationData1 = np.array([739.5, 290, 159.5, 101.5, 72.5, 87, 58])
oscillationData2 = np.array([713.92, 428.35, 305.97, 237.97, 194.71, 164.75, 142.78])

# %%
np.mean(oscillationData1)
# Out:
# 215.42857142857142

# %%
#import numpy as np
import matplotlib.pyplot as plt

f = plt.figure()

#pol1 = np.polyfit(positionData, oscillationData1, 1)
#pol_graph_1 = np.polyval(pol1, positionData)

#pol2 = np.polyfit(positionData, oscillationData2, 1)
#pol_graph_2 = np.polyval(pol2, positionData)

plt.plot(positionData, oscillationData1, 'k-', label='Експериментальні значення')
plt.plot(positionData, oscillationData2, 'b--',label='Теоретичні значення')

#plt.plot(positionData, pol_graph_1, 'y--')
#plt.plot(positionData, pol_graph_2, 'm--')

plt.title('Графік залежності U(r)')
plt.ylabel('$U, мВ$')
plt.xlabel('$r, см$')
plt.legend(loc='upper right')
plt.grid()
plt.show()
f.savefig("graph.pdf", bbox_inches='tight')
